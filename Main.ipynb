# %%
# !pip install pytesseract
# !apt-get install tesseract-ocr
from PIL import Image
import pytesseract
# !pip install pdf2image
# !apt-get install poppler-utils
from pdf2image import convert_from_path
import pytesseract
from PIL import Image


pdf = r"/content/22BCE004-Abhay Patel.pdf"

pages = convert_from_path(pdf, 500)

skills = [
    "Python", "Java", "C++", "SQL", "JavaScript", "HTML", "CSS", "Machine Learning",
    "Data Science", "Project Management", "Communication", "Leadership", "Teamwork",
    "Problem Solving", "Time Management", "Adaptability", "Creativity", "Networking",
    "Linux", "AWS", "Docker", "Kubernetes", "Git", "Agile", "Scrum"
]


identified_skills = set()

for i, page in enumerate(pages):

    image_name = f"pageFromRsume{i+1}.jpg"
    page.save(image_name, "JPEG")

    text = pytesseract.image_to_string(Image.open(f"pageFromRsume{i+1}.jpg"))

    print(f"\n------------------------ Page {i + 1} --------------------------------\n")
    print(text)

    for skill in skills:
        if skill.lower() in text.lower():
            identified_skills.add(skill)

print("\nIdentified Skills:")
for skill in sorted(identified_skills):
    print(skill)
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (1.17.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pdf2image) (9.4.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
#
# ------------------------ Page 1 --------------------------------
#
# ABHAY PATEL
#
# oF +91-8320389771 SG abhaypatel5845@gmail.com fj Abhay Patel ©) Venjix007
# Profile
#
# I’m a Sophomore pursuing a degree in Computer Science and Engg. with curiosity and eagerness to keep
# learning and explore the vast world of technology.
#
# Projects
# Arduino based Bluetooth Car | C++
# e We, as a team, created an Arduino based Car Connected via bluetooth and controlled remotely with the
# help of an application and pitched in an event named BidBots and secured the runners-up position.
# e Tools & technologies used: Used Arduino UNO, L298N Mototr Driver, BO Motor and Wheels, Battery
# And Laptop to Program it. We programmed it in Ardiono Software and provide its functionalities
# according to need.
#
#
#
# e My Experience: Acted as team leader and team coordinator. Learnt how to work as a team and
# organize the idea by understanding the perspective of each team member.
#
# Personal Finance Manager | Java
# e Developed a Personal Finance Manager to get hands on experience on java Concepts and while learning
# the language
# e Tools & technologies used: Utilized Basic java functionalities and concepts and connected it to different
# file using I/O Module provided by java .
# e Used All conecpts of OOP like Inheritance,Ploymorphism And Abstraction. Also incorprated Exception
# Handling And Multithreading in it.
#
# Blood Bank Management System | C#
#
# e Created a Ul-based blood bank management system by applying the concepts of SQL queries and
# managing the database by applying knowledge of database management systems.
#
# e Tools & technologies used: DBMS queries, Visual Code, UI Design. We combined dbms concepts and
# made a working model from it and represented it using UI.
#
# e | created a system wherein the databases of the donors and the patients that require different blood
# types and manage the same as the requirements arise. ‘This can be edited by the admin who can access
# using stored id and password hence implementation of secure login is also included.
#
# Skills
#
# Technical Skills Soft Skills
# Communication
# Languages: C, C++, JAVA, Python Team work
# Developer Tools: VS Code, Intellij Leadership
# Technologies/Frameworks: GitHub Time Management
#
# Relevant Coursework
#
# e Data Structures e OOPS
# e AI and ML e Database Management
# Education
# Nirma University Oct 2022 - May 2026
#
# Bachelors of Tech. in Computer Science and Engineering Ahmedabad, Gujarat, India
#
#
# Identified Skills:
# C++
# Communication
# Git
# Java
# Leadership
# Python
# SQL
# Time Management
